# %% [markdown]
# MODELO PARA SOLUCIONAR

# %% [markdown]
# TENEMOS YA ESA LISTA NUMERICA QUE NOS VIENEN LOS 81 VALORES NUMERICOS

# %% [markdown]
# REDES DE SOLUCION DE JUEGO

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow

# %% [markdown]
# ME PILLO 100000 REGISTROS PARA ENTRENAR AL PRINCIPIO Y COMO MAXIMO DEPENDIENDO LO QUE NOS TARDE 1 MILLON O 2

# %%
df = pd.read_csv("data/sudoku.csv", nrows=100000)
df.shape
# Out:
# (100000, 2)

# %%
df.head()
# Out:
#                                               puzzle  \
# 0  7000004304000961080063490009405200035846002000...
# 1  3010865040465210705000000014008000020803479000...
# 2  4830156036000809091067000302000093550901020067...
# 3  8317000004205109000040070327160904901450000045...
# 4  4089063000013682080074051900046705245002070026...
#
#                                             solution
# 0  6795182435437296188216349577943521863584617292...
# 1  3719865248465213795924738614638197522853479167...
# 2  7483915623652487919126754834217869355894132766...
# 3  2983176457642851391539462783271689549814537266...
# 4  1428956379751368248367425193984671524513287962...

# %%
x = df["puzzle"]
y = df["solution"]

# %%
X

# %%
modelo_rn = models.Sequential([
    layers.Input(shape=(81,)),
    layers.Densa(128, activation = "relu"),
    layers.Densa(64, activation = "relu"),
    layers.Densa(32, activation = "relu"),
    layers.Input(10, activation = "sofmax"),

    
])


modelo
